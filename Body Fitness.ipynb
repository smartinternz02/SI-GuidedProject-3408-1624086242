# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv(r"../dataset/25.csv")

# %%
data
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0   2017-10-06        5464   200              181               5
# 1   2017-10-07        6041   100              197               8
# 2   2017-10-08          25   100                0               5
# 3   2017-10-09        5461   100              174               4
# 4   2017-10-10        6915   200              223               5
# ..         ...         ...   ...              ...             ...
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# 4              500         66
# ..             ...        ...
# 91               0         64
# 92               0         64
# 93             500         64
# 94               0         64
# 95             500         64
#
# [96 rows x 7 columns]

# %%
data.values
# Out:
# array([['2017-10-06', 5464, 200, 181, 5, 0, 66],
#        ['2017-10-07', 6041, 100, 197, 8, 0, 66],
#        ['2017-10-08', 25, 100, 0, 5, 0, 66],
#        ['2017-10-09', 5461, 100, 174, 4, 0, 66],
#        ['2017-10-10', 6915, 200, 223, 5, 500, 66],
#        ['2017-10-11', 4545, 100, 149, 6, 0, 66],
#        ['2017-10-12', 4340, 100, 140, 6, 0, 66],
#        ['2017-10-13', 1230, 100, 38, 7, 0, 66],
#        ['2017-10-14', 61, 100, 1, 5, 0, 66],
#        ['2017-10-15', 1258, 100, 40, 6, 0, 65],
#        ['2017-10-16', 3148, 100, 101, 8, 0, 65],
#        ['2017-10-17', 4687, 100, 152, 5, 0, 65],
#        ['2017-10-18', 4732, 300, 150, 6, 500, 65],
#        ['2017-10-19', 3519, 100, 113, 7, 0, 65],
#        ['2017-10-20', 1580, 100, 49, 5, 0, 65],
#        ['2017-10-21', 2822, 100, 86, 6, 0, 65],
#        ['2017-10-22', 181, 100, 6, 8, 0, 65],
#        ['2017-10-23', 3158, 200, 99, 5, 0, 65],
#        ['2017-10-24', 4383, 200, 143, 4, 0, 64],
#        ['2017-10-25', 3881, 200, 125, 5, 0, 64],
#        ['2017-10-26', 4037, 200, 129, 6, 0, 64],
#        ['2017-10-27', 202, 200, 6, 8, 0, 64],
#        ['2017-10-28', 292, 200, 9, 5, 0, 64],
#        ['2017-10-29', 330, 300, 10, 6, 0, 64],
#        ['2017-10-30', 2209, 200, 72, 5, 0, 64],
#        ['2017-10-31', 4550, 300, 150, 8, 500, 64],
#        ['2017-11-01', 4435, 300, 141, 5, 0, 64],
#        ['2017-11-02', 4779, 300, 156, 4, 0, 64],
#        ['2017-11-03', 1831, 300, 57, 5, 0, 64],
#        ['2017-11-04', 2255, 300, 72, 4, 0, 64],
#        ['2017-11-05', 539, 300, 17, 5, 500, 64],
#        ['2017-11-06', 5464, 300, 181, 4, 0, 64],
#        ['2017-11-07', 6041, 200, 197, 3, 0, 64],
#        ['2017-11-08', 4068, 300, 131, 2, 0, 64],
#        ['2017-11-09', 4683, 300, 154, 9, 0, 64],
#        ['2017-11-10', 4033, 300, 137, 5, 0, 64],
#        ['2017-11-11', 6314, 300, 193, 6, 500, 64],
#        ['2017-11-12', 614, 300, 19, 4, 500, 64],
#        ['2017-11-13', 3149, 300, 101, 5, 500, 64],
#        ['2017-11-14', 4005, 300, 139, 8, 500, 64],
#        ['2017-11-15', 4880, 300, 164, 4, 500, 64],
#        ['2017-11-16', 4136, 300, 137, 5, 500, 64],
#        ['2017-11-17', 705, 300, 22, 6, 500, 64],
#        ['2017-11-18', 570, 200, 17, 5, 500, 64],
#        ['2017-11-19', 269, 300, 9, 6, 500, 64],
#        ['2017-11-20', 4275, 300, 145, 5, 0, 64],
#        ['2017-11-21', 5999, 300, 192, 6, 0, 64],
#        ['2017-11-22', 4421, 300, 146, 5, 0, 64],
#        ['2017-11-23', 6930, 300, 234, 6, 0, 64],
#        ['2017-11-24', 5195, 300, 167, 5, 0, 64],
#        ['2017-11-25', 546, 300, 16, 6, 0, 64],
#        ['2017-11-26', 493, 300, 17, 7, 500, 64],
#        ['2017-11-27', 995, 300, 32, 6, 500, 64],
#        ['2017-11-28', 1163, 200, 35, 7, 500, 64],
#        ['2017-11-29', 6676, 100, 220, 6, 500, 64],
#        ['2017-11-30', 3608, 300, 116, 5, 500, 64],
#        ['2017-12-01', 774, 300, 23, 6, 500, 64],
#        ['2017-12-02', 1421, 300, 44, 7, 500, 64],
#        ['2017-12-03', 4064, 300, 131, 8, 500, 64],
#        ['2017-12-04', 2725, 300, 86, 8, 500, 64],
#        ['2017-12-05', 5934, 300, 194, 7, 500, 64],
#        ['2017-12-06', 1867, 300, 60, 8, 500, 64],
#        ['2017-12-07', 3721, 100, 121, 5, 500, 64],
#        ['2017-12-08', 2374, 200, 76, 4, 0, 64],
#        ['2017-12-09', 2909, 200, 93, 3, 500, 64],
#        ['2017-12-10', 1648, 100, 53, 3, 500, 64],
#        ['2017-12-11', 799, 100, 25, 4, 0, 64],
#        ['2017-12-12', 7102, 200, 227, 5, 500, 64],
#        ['2017-12-13', 3941, 200, 125, 5, 500, 64],
#        ['2017-12-14', 7422, 300, 243, 5, 500, 64],
#        ['2017-12-15', 437, 200, 14, 3, 500, 64],
#        ['2017-12-16', 1231, 200, 39, 4, 500, 64],
#        ['2017-12-17', 1696, 100, 55, 4, 0, 64],
#        ['2017-12-18', 4921, 200, 158, 5, 500, 64],
#        ['2017-12-19', 221, 100, 7, 5, 500, 64],
#        ['2017-12-20', 6500, 200, 213, 5, 500, 64],
#        ['2017-12-21', 3575, 200, 116, 5, 500, 64],
#        ['2017-12-22', 4061, 100, 129, 5, 0, 64],
#        ['2017-12-23', 651, 100, 21, 5, 0, 64],
#        ['2017-12-24', 753, 100, 28, 4, 0, 64],
#        ['2017-12-25', 518, 100, 16, 3, 0, 64],
#        ['2017-12-26', 5537, 300, 180, 4, 500, 64],
#        ['2017-12-27', 4108, 200, 138, 5, 500, 64],
#        ['2017-12-28', 5376, 300, 176, 5, 500, 64],
#        ['2017-12-29', 3066, 200, 99, 4, 500, 64],
#        ['2017-12-30', 177, 100, 5, 5, 0, 64],
#        ['2017-12-31', 36, 100, 1, 3, 0, 64],
#        ['2018-01-01', 299, 100, 10, 3, 0, 64],
#        ['2018-01-02', 1447, 200, 47, 3, 0, 64],
#        ['2018-01-03', 2599, 200, 84, 2, 0, 64],
#        ['2018-01-04', 702, 100, 23, 3, 0, 64],
#        ['2018-01-05', 133, 100, 4, 2, 0, 64],
#        ['2018-01-06', 153, 300, 0, 8, 0, 64],
#        ['2018-01-07', 500, 200, 0, 5, 500, 64],
#        ['2018-01-08', 2127, 200, 0, 5, 0, 64],
#        ['2018-01-09', 2203, 300, 0, 5, 500, 64]], dtype=object)

# %%
data.head()
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
#
#    bool_of_active  weight_kg
# 0               0         66
# 1               0         66
# 2               0         66
# 3               0         66
# 4             500         66

# %%
data.tail()
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 91               0         64
# 92               0         64
# 93             500         64
# 94               0         64
# 95             500         64

# %%
data.head(8)
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
# 5  2017-10-11        4545   100              149               6
# 6  2017-10-12        4340   100              140               6
# 7  2017-10-13        1230   100               38               7
#
#    bool_of_active  weight_kg
# 0               0         66
# 1               0         66
# 2               0         66
# 3               0         66
# 4             500         66
# 5               0         66
# 6               0         66
# 7               0         66

# %%
data.columns
# Out:
# Index(['date', 'step_count', 'mood', 'calories_burned', 'hours_of_sleep',
#        'bool_of_active', 'weight_kg'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             96 non-null     object
#  1   step_count       96 non-null     int64
#  2   mood             96 non-null     int64
#  3   calories_burned  96 non-null     int64
#  4   hours_of_sleep   96 non-null     int64
#  5   bool_of_active   96 non-null     int64
#  6   weight_kg        96 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.4+ KB

# %%
data.describe()
# Out:
#         step_count        mood  calories_burned  hours_of_sleep  \
# count    96.000000   96.000000        96.000000        96.00000
# mean   2935.937500  211.458333        93.447917         5.21875
# std    2143.384573   84.442184        71.601951         1.51625
# min      25.000000  100.000000         0.000000         2.00000
# 25%     741.000000  100.000000        21.750000         4.00000
# 50%    2987.500000  200.000000        96.000000         5.00000
# 75%    4546.250000  300.000000       149.250000         6.00000
# max    7422.000000  300.000000       243.000000         9.00000
#
#        bool_of_active  weight_kg
# count       96.000000  96.000000
# mean       218.750000  64.281250
# std        249.341237   0.627495
# min          0.000000  64.000000
# 25%          0.000000  64.000000
# 50%          0.000000  64.000000
# 75%        500.000000  64.000000
# max        500.000000  66.000000

# %%
np.unique(data.dtypes,return_counts=True)
# Out:
# (array([dtype('int64'), dtype('O')], dtype=object), array([6, 1], dtype=int64))

# %%
def category(data):
    for i in data.columns:
        print(i)
        print(data[i].unique())
        print("x"*90)
category(data)
# Out:
# date
# ['2017-10-06' '2017-10-07' '2017-10-08' '2017-10-09' '2017-10-10'
#  '2017-10-11' '2017-10-12' '2017-10-13' '2017-10-14' '2017-10-15'
#  '2017-10-16' '2017-10-17' '2017-10-18' '2017-10-19' '2017-10-20'
#  '2017-10-21' '2017-10-22' '2017-10-23' '2017-10-24' '2017-10-25'
#  '2017-10-26' '2017-10-27' '2017-10-28' '2017-10-29' '2017-10-30'
#  '2017-10-31' '2017-11-01' '2017-11-02' '2017-11-03' '2017-11-04'
#  '2017-11-05' '2017-11-06' '2017-11-07' '2017-11-08' '2017-11-09'
#  '2017-11-10' '2017-11-11' '2017-11-12' '2017-11-13' '2017-11-14'
#  '2017-11-15' '2017-11-16' '2017-11-17' '2017-11-18' '2017-11-19'
#  '2017-11-20' '2017-11-21' '2017-11-22' '2017-11-23' '2017-11-24'
#  '2017-11-25' '2017-11-26' '2017-11-27' '2017-11-28' '2017-11-29'
#  '2017-11-30' '2017-12-01' '2017-12-02' '2017-12-03' '2017-12-04'
#  '2017-12-05' '2017-12-06' '2017-12-07' '2017-12-08' '2017-12-09'
#  '2017-12-10' '2017-12-11' '2017-12-12' '2017-12-13' '2017-12-14'
#  '2017-12-15' '2017-12-16' '2017-12-17' '2017-12-18' '2017-12-19'
#  '2017-12-20' '2017-12-21' '2017-12-22' '2017-12-23' '2017-12-24'
#  '2017-12-25' '2017-12-26' '2017-12-27' '2017-12-28' '2017-12-29'
#  '2017-12-30' '2017-12-31' '2018-01-01' '2018-01-02' '2018-01-03'
#  '2018-01-04' '2018-01-05' '2018-01-06' '2018-01-07' '2018-01-08'
#  '2018-01-09']
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# step_count
# [5464 6041   25 5461 6915 4545 4340 1230   61 1258 3148 4687 4732 3519
#  1580 2822  181 3158 4383 3881 4037  202  292  330 2209 4550 4435 4779
#  1831 2255  539 4068 4683 4033 6314  614 3149 4005 4880 4136  705  570
#   269 4275 5999 4421 6930 5195  546  493  995 1163 6676 3608  774 1421
#  4064 2725 5934 1867 3721 2374 2909 1648  799 7102 3941 7422  437 1231
#  1696 4921  221 6500 3575 4061  651  753  518 5537 4108 5376 3066  177
#    36  299 1447 2599  702  133  153  500 2127 2203]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# mood
# [200 100 300]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# calories_burned
# [181 197   0 174 223 149 140  38   1  40 101 152 150 113  49  86   6  99
#  143 125 129   9  10  72 141 156  57  17 131 154 137 193  19 139 164  22
#  145 192 146 234 167  16  32  35 220 116  23  44 194  60 121  76  93  53
#   25 227 243  14  39  55 158   7 213  21  28 180 138 176   5  47  84   4]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# hours_of_sleep
# [5 8 4 6 7 3 2 9]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# bool_of_active
# [  0 500]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# weight_kg
# [66 65 64]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
data.corr()
# Out:
#                  step_count      mood  calories_burned  hours_of_sleep  \
# step_count         1.000000  0.246738         0.989260        0.080687
# mood               0.246738  1.000000         0.235044        0.210417
# calories_burned    0.989260  0.235044         1.000000        0.080726
# hours_of_sleep     0.080687  0.210417         0.080726        1.000000
# bool_of_active     0.120212  0.379646         0.110900        0.136603
# weight_kg          0.109404 -0.458776         0.112200        0.189118
#
#                  bool_of_active  weight_kg
# step_count             0.120212   0.109404
# mood                   0.379646  -0.458776
# calories_burned        0.110900   0.112200
# hours_of_sleep         0.136603   0.189118
# bool_of_active         1.000000  -0.296443
# weight_kg             -0.296443   1.000000

# %%
data.isnull()
# Out:
#      date  step_count   mood  calories_burned  hours_of_sleep  bool_of_active  \
# 0   False       False  False            False           False           False
# 1   False       False  False            False           False           False
# 2   False       False  False            False           False           False
# 3   False       False  False            False           False           False
# 4   False       False  False            False           False           False
# ..    ...         ...    ...              ...             ...             ...
# 91  False       False  False            False           False           False
# 92  False       False  False            False           False           False
# 93  False       False  False            False           False           False
# 94  False       False  False            False           False           False
# 95  False       False  False            False           False           False
#
#     weight_kg
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 91      False
# 92      False
# 93      False
# 94      False
# 95      False
#
# [96 rows x 7 columns]

# %%
data.isnull().any()
# Out:
# date               False
# step_count         False
# mood               False
# calories_burned    False
# hours_of_sleep     False
# bool_of_active     False
# weight_kg          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# date               0
# step_count         0
# mood               0
# calories_burned    0
# hours_of_sleep     0
# bool_of_active     0
# weight_kg          0
# dtype: int64

# %%
sns.heatmap(data.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Label Encoding the target column

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['bool_of_active']=le.fit_transform(data['bool_of_active'])
data
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0   2017-10-06        5464   200              181               5
# 1   2017-10-07        6041   100              197               8
# 2   2017-10-08          25   100                0               5
# 3   2017-10-09        5461   100              174               4
# 4   2017-10-10        6915   200              223               5
# ..         ...         ...   ...              ...             ...
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# 4                1         66
# ..             ...        ...
# 91               0         64
# 92               0         64
# 93               1         64
# 94               0         64
# 95               1         64
#
# [96 rows x 7 columns]

# %%
data['step_count'].hist()
# Out:
# <AxesSubplot:>

# %%
data['calories_burned'].hist()
# Out:
# <AxesSubplot:>

# %%
data['weight_kg'].hist()
# Out:
# <AxesSubplot:>

# %%
data['hours_of_sleep'].hist()
# Out:
# <AxesSubplot:>

# %%
corr=data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
sns.set_style("whitegrid")
sns.pairplot(data)

# %%
data['step_count'].groupby(data.mood).describe()
# Out:
#       count         mean          std    min     25%     50%      75%     max
# mood
# 100    29.0  2103.068966  2057.012361   25.0   299.0  1258.0  3721.00  6676.0
# 200    27.0  3153.777778  2091.761446  202.0  1339.0  3066.0  4245.50  7102.0
# 300    40.0  3392.725000  2115.006540  153.0  1314.5  4048.5  4804.25  7422.0

# %%
sns.barplot(x="mood",y="step_count",data=data)
plt.title("Comparison of step count by mood perception")
plt.legend(['100 = Sad', '200 = Neutral', '300 = Happy'],loc='upper left',prop={'size':7})
plt.figure(figsize=(6,5))

# %%
data['step_count'].groupby(data.bool_of_active).describe()
# Out:
#                 count         mean          std    min      25%     50%  \
# bool_of_active
# 0                54.0  2709.888889  2059.107323   25.0   663.75  2486.5
# 1                42.0  3226.571429  2238.337734  221.0  1037.00  3362.0
#
#                    75%     max
# bool_of_active
# 0               4411.5  6930.0
# 1               4843.0  7422.0

# %%
sns.barplot(x='bool_of_active', y='step_count', data=data)
plt.legend(['0= Inactive', '500 = Active'])

# %%
data.boxplot(column="step_count")
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column="calories_burned")
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['bool_of_active']=le.fit_transform(data['bool_of_active'])
data
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0   2017-10-06        5464   200              181               5
# 1   2017-10-07        6041   100              197               8
# 2   2017-10-08          25   100                0               5
# 3   2017-10-09        5461   100              174               4
# 4   2017-10-10        6915   200              223               5
# ..         ...         ...   ...              ...             ...
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# 4                1         66
# ..             ...        ...
# 91               0         64
# 92               0         64
# 93               1         64
# 94               0         64
# 95               1         64
#
# [96 rows x 7 columns]

# %%
x=pd.DataFrame(data.iloc[:,[1,2,3,4,6]])
y=pd.DataFrame(data.iloc[:,5])

# %%
x
# Out:
#     step_count  mood  calories_burned  hours_of_sleep  weight_kg
# 0         5464   200              181               5         66
# 1         6041   100              197               8         66
# 2           25   100                0               5         66
# 3         5461   100              174               4         66
# 4         6915   200              223               5         66
# ..         ...   ...              ...             ...        ...
# 91         133   100                4               2         64
# 92         153   300                0               8         64
# 93         500   200                0               5         64
# 94        2127   200                0               5         64
# 95        2203   300                0               5         64
#
# [96 rows x 5 columns]

# %%
x.values
# Out:
# array([[5464,  200,  181,    5,   66],
#        [6041,  100,  197,    8,   66],
#        [  25,  100,    0,    5,   66],
#        [5461,  100,  174,    4,   66],
#        [6915,  200,  223,    5,   66],
#        [4545,  100,  149,    6,   66],
#        [4340,  100,  140,    6,   66],
#        [1230,  100,   38,    7,   66],
#        [  61,  100,    1,    5,   66],
#        [1258,  100,   40,    6,   65],
#        [3148,  100,  101,    8,   65],
#        [4687,  100,  152,    5,   65],
#        [4732,  300,  150,    6,   65],
#        [3519,  100,  113,    7,   65],
#        [1580,  100,   49,    5,   65],
#        [2822,  100,   86,    6,   65],
#        [ 181,  100,    6,    8,   65],
#        [3158,  200,   99,    5,   65],
#        [4383,  200,  143,    4,   64],
#        [3881,  200,  125,    5,   64],
#        [4037,  200,  129,    6,   64],
#        [ 202,  200,    6,    8,   64],
#        [ 292,  200,    9,    5,   64],
#        [ 330,  300,   10,    6,   64],
#        [2209,  200,   72,    5,   64],
#        [4550,  300,  150,    8,   64],
#        [4435,  300,  141,    5,   64],
#        [4779,  300,  156,    4,   64],
#        [1831,  300,   57,    5,   64],
#        [2255,  300,   72,    4,   64],
#        [ 539,  300,   17,    5,   64],
#        [5464,  300,  181,    4,   64],
#        [6041,  200,  197,    3,   64],
#        [4068,  300,  131,    2,   64],
#        [4683,  300,  154,    9,   64],
#        [4033,  300,  137,    5,   64],
#        [6314,  300,  193,    6,   64],
#        [ 614,  300,   19,    4,   64],
#        [3149,  300,  101,    5,   64],
#        [4005,  300,  139,    8,   64],
#        [4880,  300,  164,    4,   64],
#        [4136,  300,  137,    5,   64],
#        [ 705,  300,   22,    6,   64],
#        [ 570,  200,   17,    5,   64],
#        [ 269,  300,    9,    6,   64],
#        [4275,  300,  145,    5,   64],
#        [5999,  300,  192,    6,   64],
#        [4421,  300,  146,    5,   64],
#        [6930,  300,  234,    6,   64],
#        [5195,  300,  167,    5,   64],
#        [ 546,  300,   16,    6,   64],
#        [ 493,  300,   17,    7,   64],
#        [ 995,  300,   32,    6,   64],
#        [1163,  200,   35,    7,   64],
#        [6676,  100,  220,    6,   64],
#        [3608,  300,  116,    5,   64],
#        [ 774,  300,   23,    6,   64],
#        [1421,  300,   44,    7,   64],
#        [4064,  300,  131,    8,   64],
#        [2725,  300,   86,    8,   64],
#        [5934,  300,  194,    7,   64],
#        [1867,  300,   60,    8,   64],
#        [3721,  100,  121,    5,   64],
#        [2374,  200,   76,    4,   64],
#        [2909,  200,   93,    3,   64],
#        [1648,  100,   53,    3,   64],
#        [ 799,  100,   25,    4,   64],
#        [7102,  200,  227,    5,   64],
#        [3941,  200,  125,    5,   64],
#        [7422,  300,  243,    5,   64],
#        [ 437,  200,   14,    3,   64],
#        [1231,  200,   39,    4,   64],
#        [1696,  100,   55,    4,   64],
#        [4921,  200,  158,    5,   64],
#        [ 221,  100,    7,    5,   64],
#        [6500,  200,  213,    5,   64],
#        [3575,  200,  116,    5,   64],
#        [4061,  100,  129,    5,   64],
#        [ 651,  100,   21,    5,   64],
#        [ 753,  100,   28,    4,   64],
#        [ 518,  100,   16,    3,   64],
#        [5537,  300,  180,    4,   64],
#        [4108,  200,  138,    5,   64],
#        [5376,  300,  176,    5,   64],
#        [3066,  200,   99,    4,   64],
#        [ 177,  100,    5,    5,   64],
#        [  36,  100,    1,    3,   64],
#        [ 299,  100,   10,    3,   64],
#        [1447,  200,   47,    3,   64],
#        [2599,  200,   84,    2,   64],
#        [ 702,  100,   23,    3,   64],
#        [ 133,  100,    4,    2,   64],
#        [ 153,  300,    0,    8,   64],
#        [ 500,  200,    0,    5,   64],
#        [2127,  200,    0,    5,   64],
#        [2203,  300,    0,    5,   64]], dtype=int64)

# %%
y
# Out:
#     bool_of_active
# 0                0
# 1                0
# 2                0
# 3                0
# 4              500
# ..             ...
# 91               0
# 92               0
# 93             500
# 94               0
# 95             500
#
# [96 rows x 1 columns]

# %%
columnTransformer = ColumnTransformer([('encoder',OneHotEncoder(),[1])],remainder='passthrough')
x=pd.DataFrame(columnTransformer.fit_transform(x),dtype=np.str,columns=['sad','neutral','happy','step_count','calories_burned','hours_of_sleep','weight_kg'])

# %%
x
# Out:
#     sad neutral happy step_count calories_burned hours_of_sleep weight_kg
# 0   0.0     1.0   0.0     5464.0           181.0            5.0      66.0
# 1   1.0     0.0   0.0     6041.0           197.0            8.0      66.0
# 2   1.0     0.0   0.0       25.0             0.0            5.0      66.0
# 3   1.0     0.0   0.0     5461.0           174.0            4.0      66.0
# 4   0.0     1.0   0.0     6915.0           223.0            5.0      66.0
# ..  ...     ...   ...        ...             ...            ...       ...
# 91  1.0     0.0   0.0      133.0             4.0            2.0      64.0
# 92  0.0     0.0   1.0      153.0             0.0            8.0      64.0
# 93  0.0     1.0   0.0      500.0             0.0            5.0      64.0
# 94  0.0     1.0   0.0     2127.0             0.0            5.0      64.0
# 95  0.0     0.0   1.0     2203.0             0.0            5.0      64.0
#
# [96 rows x 7 columns]

# %%
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=0)

# %%
dtc=DecisionTreeClassifier(max_depth=12)
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=12)

# %%
dt_y_train=dtc.predict([['0.0','0.0','1.0','4435.0','141.0','5.0','64.0']])
dt_y_train
# Out:
# array([0], dtype=int64)

# %%
dt_y_train
# Out:
# array([0], dtype=int64)

# %%
dtc.score(dt_y_train,x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-47f86fab6671> in <module>
# ----> 1 dtc.score(dt_y_train,x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     497         """
#     498         from .metrics import accuracy_score
# --> 499         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     500
#     501     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     425         """
#     426         check_is_fitted(self)
# --> 427         X = self._validate_X_predict(X, check_input)
#     428         proba = self.tree_.predict(X)
#     429         n_samples = X.shape[0]
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     386         """Validate X whenever one tries to predict, apply, predict_proba"""
#     387         if check_input:
# --> 388             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     389             if issparse(X) and (X.indices.dtype != np.intc or
#     390                                 X.indptr.dtype != np.intc):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     617             # If input is 1D raise error
#     618             if array.ndim == 1:
# --> 619                 raise ValueError(
#     620                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     621                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
dtc.score(x_train,y_train)
# Out:
# 0.9883720930232558

# %%
import pickle
pickle.dump(dtc,open('fitness.pkl','wb'))
